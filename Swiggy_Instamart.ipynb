# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjan234/-Descriptive-Statistics-Case-Study/blob/main/Swiggy_Instamart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello everyone!")
# Out:
# Hello everyone!

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv('Customers.csv')
customers
# Out:
#      CustomerID             Name       Phone                  Address  \
# 0             1      Kavya Reddy  9193214172       Koramangala, Delhi
# 1             2  Siddharth Joshi  1628503012      Civil Lines, Jaipur
# 2             3       Neha Joshi  6430427670   Civil Lines, Hyderabad
# 3             4  Siddharth Mehta  2645852001          MG Road, Jaipur
# 4             5     Rajesh Reddy  2428071930        Koramangala, Pune
# ..          ...              ...         ...                      ...
# 295         296     Rohit Sharma  6671028571    Gachibowli, Bangalore
# 296         297  Siddharth Joshi  6721377969      Malviya Nagar, Pune
# 297         298     Aarav Sharma  6633244842  Andheri West, Ahmedabad
# 298         299      Pooja Gupta  8413555089       Civil Lines, Delhi
# 299         300    Rajesh Sharma   640341465           MG Road, Delhi
#
#           City
# 0       Mumbai
# 1         Pune
# 2       Jaipur
# 3       Jaipur
# 4    Ahmedabad
# ..         ...
# ...

# %%
customers.head(5)
# Out:
#    CustomerID             Name       Phone                 Address       City
# 0           1      Kavya Reddy  9193214172      Koramangala, Delhi     Mumbai
# 1           2  Siddharth Joshi  1628503012     Civil Lines, Jaipur       Pune
# 2           3       Neha Joshi  6430427670  Civil Lines, Hyderabad     Jaipur
# 3           4  Siddharth Mehta  2645852001         MG Road, Jaipur     Jaipur
# 4           5     Rajesh Reddy  2428071930       Koramangala, Pune  Ahmedabad

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  300 non-null    int64
#  1   Name        300 non-null    object
#  2   Phone       300 non-null    int64
#  3   Address     300 non-null    object
#  4   City        300 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 11.8+ KB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           4000 non-null   int64
#  1   CustomerID        4000 non-null   int64
#  2   OrderDateTime     4000 non-null   object
#  3   DeliveryDateTime  3924 non-null   object
#  4   TotalAmount       4000 non-null   int64
#  5   DeliveryStatus    4000 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
orderdetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderDetailsID  10000 non-null  int64
#  1   OrderID         10000 non-null  int64
#  2   ProductName     10000 non-null  object
#  3   Quantity        10000 non-null  int64
#  4   PricePerUnit    10000 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 390.8+ KB

# %%
customers.isnull()
# Out:
#      CustomerID   Name  Phone  Address   City
# 0         False  False  False    False  False
# 1         False  False  False    False  False
# 2         False  False  False    False  False
# 3         False  False  False    False  False
# 4         False  False  False    False  False
# ..          ...    ...    ...      ...    ...
# 295       False  False  False    False  False
# 296       False  False  False    False  False
# 297       False  False  False    False  False
# 298       False  False  False    False  False
# 299       False  False  False    False  False
#
# [300 rows x 5 columns]

# %%
# How to check null values. null means it is not aplicable.
customers.isnull().sum()
# Out:
# CustomerID    0
# Name          0
# Phone         0
# Address       0
# City          0
# dtype: int64

# %%
orders.isnull().sum()
# Out:
# OrderID              0
# CustomerID           0
# OrderDateTime        0
# DeliveryDateTime    76
# TotalAmount          0
# DeliveryStatus       0
# dtype: int64

# %%
orderdetails.isnull().sum()
# Out:
# OrderDetailsID    0
# OrderID           0
# ProductName       0
# Quantity          0
# PricePerUnit      0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# Length: 4000, dtype: bool

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orderdetails.duplicated().sum()
# Out:
# np.int64(0)

# %%
# If your data contains duplicated values use the following code
customers.drop_duplicates()
# Out:
#      CustomerID             Name       Phone                  Address  \
# 0             1      Kavya Reddy  9193214172       Koramangala, Delhi
# 1             2  Siddharth Joshi  1628503012      Civil Lines, Jaipur
# 2             3       Neha Joshi  6430427670   Civil Lines, Hyderabad
# 3             4  Siddharth Mehta  2645852001          MG Road, Jaipur
# 4             5     Rajesh Reddy  2428071930        Koramangala, Pune
# ..          ...              ...         ...                      ...
# 295         296     Rohit Sharma  6671028571    Gachibowli, Bangalore
# 296         297  Siddharth Joshi  6721377969      Malviya Nagar, Pune
# 297         298     Aarav Sharma  6633244842  Andheri West, Ahmedabad
# 298         299      Pooja Gupta  8413555089       Civil Lines, Delhi
# 299         300    Rajesh Sharma   640341465           MG Road, Delhi
#
#           City
# 0       Mumbai
# 1         Pune
# 2       Jaipur
# 3       Jaipur
# 4    Ahmedabad
# ..         ...
# ...

# %%
city_count  = customers.groupby('City').count()
city_count
# Out:
#            CustomerID  Name  Phone  Address
# City
# Ahmedabad          46    46     46       46
# Bangalore          34    34     34       34
# Delhi              37    37     37       37
# Hyderabad          48    48     48       48
# Jaipur             49    49     49       49
# Mumbai             47    47     47       47
# Pune               39    39     39       39

# %% [markdown]
# *   List item
# *   List item

# %%
city_count  = customers.groupby('City').agg({"CustomerID":"count"})
city_count
# Out:
#            CustomerID
# City
# Ahmedabad          46
# Bangalore          34
# Delhi              37
# Hyderabad          48
# Jaipur             49
# Mumbai             47
# Pune               39

# %%
# how to remove null values
orders.dropna()
# Out:
#       OrderID  CustomerID        OrderDateTime     DeliveryDateTime  \
# 0           1          17  2024-11-17 22:12:56  2024-11-17 22:27:56
# 1           2          71  2024-11-13 10:52:56  2024-11-13 11:03:56
# 2           3           2  2024-10-25 03:06:56  2024-10-25 03:17:56
# 3           4         155  2024-10-13 20:52:56  2024-10-13 21:05:56
# 4           5         270  2024-10-22 05:01:56  2024-10-22 05:12:56
# ...       ...         ...                  ...                  ...
# 3995     3996         163  2024-11-15 17:59:56  2024-11-15 18:16:56
# 3996     3997          13  2024-11-09 10:02:56  2024-11-09 10:18:56
# 3997     3998          97  2024-11-10 22:47:56  2024-11-10 22:58:56
# 3998     3999         273  2024-09-30 22:37:56  2024-09-30 22:45:56
# 3999     4000         261  2024-11-07 09:38:56  2024-11-07 09:48:56
#
#       TotalAmount DeliveryStatus
# 0             113      Delivered
# 1            1170      Delivered
# 2             837      Delivered
# ...

# %%
orders.isnull().sum()
# Out:
# OrderID              0
# CustomerID           0
# OrderDateTime        0
# DeliveryDateTime    76
# TotalAmount          0
# DeliveryStatus       0
# dtype: int64

# %%
order_count = orders.groupby('DeliveryStatus').agg({"OrderID":"count"})
order_count
# Out:
#                 OrderID
# DeliveryStatus
# Cancelled            76
# Delivered          3924

# %%
from os.path import join
# How much revenue  generated in the city.
join_orders_customers = pd.merge(orders,customers,on='CustomerID', how ="inner")
join_orders_customers
# Out:
#       OrderID  CustomerID        OrderDateTime     DeliveryDateTime  \
# 0           1          17  2024-11-17 22:12:56  2024-11-17 22:27:56
# 1           2          71  2024-11-13 10:52:56  2024-11-13 11:03:56
# 2           3           2  2024-10-25 03:06:56  2024-10-25 03:17:56
# 3           4         155  2024-10-13 20:52:56  2024-10-13 21:05:56
# 4           5         270  2024-10-22 05:01:56  2024-10-22 05:12:56
# ...       ...         ...                  ...                  ...
# 3995     3996         163  2024-11-15 17:59:56  2024-11-15 18:16:56
# 3996     3997          13  2024-11-09 10:02:56  2024-11-09 10:18:56
# 3997     3998          97  2024-11-10 22:47:56  2024-11-10 22:58:56
# 3998     3999         273  2024-09-30 22:37:56  2024-09-30 22:45:56
# 3999     4000         261  2024-11-07 09:38:56  2024-11-07 09:48:56
#
#       TotalAmount DeliveryStatus             Name       Phone  \
# 0             113      Delivered     Rohit Pandey  4625735153
# ...

# %%
revenue_city = join_orders_customers.groupby(['City','DeliveryStatus']).agg({"OrderID":"count","TotalAmount":"sum"})
revenue_city
# Out:
#                           OrderID  TotalAmount
# City      DeliveryStatus
# Ahmedabad Cancelled             6         6578
#           Delivered           592       475208
# Bangalore Cancelled             9         5960
#           Delivered           466       373445
# Delhi     Cancelled            15        13225
#           Delivered           486       383151
# Hyderabad Cancelled            11         9541
#           Delivered           620       512445
# Jaipur    Cancelled            16        11799
#           Delivered           642       515888
# Mumbai    Cancelled             8         7303
#           Delivered           618       504781
# Pune      Cancelled            11         8898
#           Delivered           500       392266

# %%
status = join_orders_customers.groupby('DeliveryStatus').agg({"TotalAmount":"sum"})
status
# Out:
#                 TotalAmount
# DeliveryStatus
# Cancelled             63304
# Delivered           3157184

# %%
sns.barplot(x=status.index,y="TotalAmount",data=status)
plt.title(" ")
plt.show()

# %%
sns.barplot(x=status.index,y ="TotalAmount",data=status, color= "orange")
plt.title("Sales by Delivery Status")
plt.show()

# %%
plt.pie(status["TotalAmount"], labels = status.index, colors= ["red","green"], autopct = "%1.2f%%")
plt.show()

# %%
orders.head(5)
# Out:
#    OrderID  CustomerID        OrderDateTime     DeliveryDateTime  TotalAmount  \
# 0        1          17  2024-11-17 22:12:56  2024-11-17 22:27:56          113
# 1        2          71  2024-11-13 10:52:56  2024-11-13 11:03:56         1170
# 2        3           2  2024-10-25 03:06:56  2024-10-25 03:17:56          837
# 3        4         155  2024-10-13 20:52:56  2024-10-13 21:05:56          357
# 4        5         270  2024-10-22 05:01:56  2024-10-22 05:12:56          410
#
#   DeliveryStatus
# 0      Delivered
# 1      Delivered
# 2      Delivered
# 3      Delivered
# 4      Delivered

# %%
orderdetails.head(5)
# Out:
#    OrderDetailsID  OrderID            ProductName  Quantity  PricePerUnit
# 0               1     2262    Clinic Plus Shampoo         1            99
# 1               2      115          Maggi Noodles         5           120
# 2               3     3872  Harpic Toilet Cleaner         4           300
# 3               4     3489        Ariel Detergent         5            99
# 4               5     1717              Bournvita         3            99

# %%
# datetime conversion
orders.info()
orders["OrderDateTime"] =pd.to_datetime(orders["OrderDateTime"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           4000 non-null   int64
#  1   CustomerID        4000 non-null   int64
#  2   OrderDateTime     4000 non-null   object
#  3   DeliveryDateTime  3924 non-null   object
#  4   TotalAmount       4000 non-null   int64
#  5   DeliveryStatus    4000 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           4000 non-null   int64
#  1   CustomerID        4000 non-null   int64
#  2   OrderDateTime     4000 non-null   datetime64[ns]
#  3   DeliveryDateTime  3924 non-null   object
#  4   TotalAmount       4000 non-null   int64
#  5   DeliveryStatus    4000 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 187.6+ KB

# %%
customers.describe()
# Out:
#        CustomerID         Phone
# count  300.000000  3.000000e+02
# mean   150.500000  5.071988e+09
# std     86.746758  2.924401e+09
# min      1.000000  3.459278e+07
# 25%     75.750000  2.413212e+09
# 50%    150.500000  5.171566e+09
# 75%    225.250000  7.598009e+09
# max    300.000000  9.995983e+09

# %%
orders.describe()
# Out:
#            OrderID   CustomerID  TotalAmount
# count  4000.000000  4000.000000  4000.000000
# mean   2000.500000   149.849500   805.122000
# std    1154.844867    87.733156   406.873926
# min       1.000000     1.000000   100.000000
# 25%    1000.750000    74.000000   452.000000
# 50%    2000.500000   147.000000   813.000000
# 75%    3000.250000   228.000000  1160.000000
# max    4000.000000   300.000000  1500.000000

# %%
orders = pd.read_csv('Orders.csv')
orders
# Out:
#       OrderID  CustomerID        OrderDateTime     DeliveryDateTime  \
# 0           1          17  2024-11-17 22:12:56  2024-11-17 22:27:56
# 1           2          71  2024-11-13 10:52:56  2024-11-13 11:03:56
# 2           3           2  2024-10-25 03:06:56  2024-10-25 03:17:56
# 3           4         155  2024-10-13 20:52:56  2024-10-13 21:05:56
# 4           5         270  2024-10-22 05:01:56  2024-10-22 05:12:56
# ...       ...         ...                  ...                  ...
# 3995     3996         163  2024-11-15 17:59:56  2024-11-15 18:16:56
# 3996     3997          13  2024-11-09 10:02:56  2024-11-09 10:18:56
# 3997     3998          97  2024-11-10 22:47:56  2024-11-10 22:58:56
# 3998     3999         273  2024-09-30 22:37:56  2024-09-30 22:45:56
# 3999     4000         261  2024-11-07 09:38:56  2024-11-07 09:48:56
#
#       TotalAmount DeliveryStatus
# 0             113      Delivered
# 1            1170      Delivered
# 2             837      Delivered
# ...

# %%
orderdetails = pd.read_csv('OrderDetails.csv')
orderdetails
# Out:
#       OrderDetailsID  OrderID            ProductName  Quantity  PricePerUnit
# 0                  1     2262    Clinic Plus Shampoo         1            99
# 1                  2      115          Maggi Noodles         5           120
# 2                  3     3872  Harpic Toilet Cleaner         4           300
# 3                  4     3489        Ariel Detergent         5            99
# 4                  5     1717              Bournvita         3            99
# ...              ...      ...                    ...       ...           ...
# 9995            9996     1240       Good Day Cookies         5            80
# 9996            9997      946       Parle-G Biscuits         1           130
# 9997            9998     2576          Maggi Noodles         2            35
# 9998            9999     2336            Fortune Oil         1            99
# 9999           10000     2932  Harpic Toilet Cleaner         3            40
#
# [10000 rows x 5 columns]
